# %%
def rotate_image(image, angle):
    """
    Rotates an image by a given angle (degrees).
    Positive angle = Counter-Clockwise rotation.
    """
    image_center = tuple(np.array(image.shape[1::-1]) / 2)
    rot_mat = cv2.getRotationMatrix2D(image_center, angle, 1.0)
    result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
    return result

# %%
import cv2
import matplotlib.pyplot as plt
# from mushroom_body.process_images_gaby import rotate_image
import numpy as np
import os

# Update this path to point to your local data
project_root = os.path.join(os.path.dirname(os.getcwd()), '')
image_path = os.path.join(project_root, "forest", "forest_6_trees_home_circle_1000_mushroom_norotation", "Replicator", "rgb", "rgb_0000.png")
img = cv2.imread(image_path)
rotated_img = rotate_image(img, -90)

# show both images side by side
plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title("Original Image")
plt.subplot(1, 2, 2)
plt.imshow(rotated_img)
plt.title("Rotated Image")
plt.show()

# %%
# Load a PN vector and print it
path = os.path.join(project_root, "forest", "forest_6_trees_home_circle_1000_mushroom", "Replicator", "PN", "rgb_0000.npy")
img = np.load(path)
print(img)
